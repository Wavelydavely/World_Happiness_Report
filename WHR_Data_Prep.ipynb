# %%
# Dependencies and Setup
import pandas as pd
import numpy as np


# Read data and store into a Pandas DataFrame
world_happiness_df = pd.read_csv("Resources/world-happiness-report.csv")
world_happiness_df.head()
# Out:
#   Country_name  year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption  Positive_affect  Negative_affect
# ...

# %%
world_happiness_df = world_happiness_df.drop(["Positive_affect", "Negative_affect"], axis = 1)
world_happiness_df.head()
# Out:
#   Country_name  year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption
# 0                      0.882
# ...

# %%
world_happiness_df.rename(columns = {'Country_name': 'Country', 'year': 'Year', 'Life_Ladder': 'Happiness_Score', 'Log_GDP_per_capita': 'Economic_Production', 'Social_support': 'Social_Support', 'Healthy_life_expectancy_at_birth': 'Life_Expectancy', 'Freedom_to_make_life_choices': 'Freedom', 'Perceptions_of_corruption': 'Perceptions_of_Corruption'}, inplace = True)
world_happiness_df.head()
# Out:
#        Country  Year  Happiness_Score  Economic_Production  Social_Support  \
# 0  Afghanistan  2008            3.724                7.370           0.451
# 1  Afghanistan  2009            4.402                7.540           0.552
# 2  Afghanistan  2010            4.758                7.647           0.539
# 3  Afghanistan  2011            3.832                7.620           0.521
# 4  Afghanistan  2012            3.783                7.705           0.521
#
#    Life_Expectancy  Freedom  Generosity  Perceptions_of_Corruption
# 0            50.80    0.718       0.168                      0.882
# 1            51.20    0.679       0.190                      0.850
# 2            51.60    0.600       0.121                      0.707
# 3            51.92    0.496       0.162                      0.731
# 4            52.24    0.531       0.236                      0.776

# %%
world_happiness_df.dtypes
# Out:
# Country                       object
# Year                           int64
# Happiness_Score              float64
# Economic_Production          float64
# Social_Support               float64
# Life_Expectancy              float64
# Freedom                      float64
# Generosity                   float64
# Perceptions_of_Corruption    float64
# dtype: object

# %%
world_happiness_df.to_csv('Cleaned_Data/World_Happiness_Report_All_Years.csv', index=False)

# %%
# Read data and store into a Pandas DataFrame
world_happiness_2021_df = pd.read_csv("Resources/world-happiness-report-2021.csv")
world_happiness_2021_df.head()
# Out:
#   Country_name Regional_indicator  Ladder_score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard_error_of_ladder_score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged_GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
world_happiness_2021_df.set_index('Country_name')
world_happiness_2021_df.head()
# Out:
#   Country_name Regional_indicator  Ladder_score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard_error_of_ladder_score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged_GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
world_happiness_2021_df = world_happiness_2021_df.drop(["Standard_error_of_ladder_score", "upperwhisker", "lowerwhisker", "Ladder_score_in_Dystopia", "Explained_by_Log_GDP_per_capita", "Explained_by_Social_support", "Explained_by_Healthy_life_expectancy", "Explained_by_Freedom_to_make_life_choices", "Explained_by_Generosity", "Explained_by_Perceptions_of_corruption", "Dystopia_residual"], axis = 1)
world_happiness_2021_df.head()
# Out:
#   Country_name Regional_indicator  Ladder_score  Logged_GDP_per_capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions_of_corruption
# 0      -0.098                      0.186
# ...

# %%
world_happiness_2021_df.rename(columns = {'Regional_indicator': 'World_Region', 'Country_name': 'Country', 'Ladder_score': 'Happiness_Score', 'Logged_GDP_per_capita': 'Economic_Production', 'Social_support': 'Social_Support', 'Healthy_life_expectancy': 'Life_Expectancy', 'Freedom_to_make_life_choices': 'Freedom', 'Perceptions_of_corruption': 'Perceptions_of_Corruption'}, inplace = True)
world_happiness_2021_df.head()
# Out:
#        Country    World_Region  Happiness_Score  Economic_Production  \
# 0      Finland  Western Europe            7.842               10.775
# 1      Denmark  Western Europe            7.620               10.933
# 2  Switzerland  Western Europe            7.571               11.117
# 3      Iceland  Western Europe            7.554               10.878
# 4  Netherlands  Western Europe            7.464               10.932
#
#    Social_Support  Life_Expectancy  Freedom  Generosity  \
# 0           0.954             72.0    0.949      -0.098
# 1           0.954             72.7    0.946       0.030
# 2           0.942             74.4    0.919       0.025
# 3           0.983             73.0    0.955       0.160
# 4           0.942             72.4    0.913       0.175
#
#    Perceptions_of_Corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292
# 3                      0.673
# 4                      0.338

# %%
#world_happiness_2021_df['Year'] = world_happiness_2021_df.apply(lambda _: "2021", axis=1)
world_happiness_2021_df.insert(1, "Year", 2021)
world_happiness_2021_df.head()
# Out:
#        Country  Year    World_Region  Happiness_Score  Economic_Production  \
# 0      Finland  2021  Western Europe            7.842               10.775
# 1      Denmark  2021  Western Europe            7.620               10.933
# 2  Switzerland  2021  Western Europe            7.571               11.117
# 3      Iceland  2021  Western Europe            7.554               10.878
# 4  Netherlands  2021  Western Europe            7.464               10.932
#
#    Social_Support  Life_Expectancy  Freedom  Generosity  \
# 0           0.954             72.0    0.949      -0.098
# 1           0.954             72.7    0.946       0.030
# 2           0.942             74.4    0.919       0.025
# 3           0.983             73.0    0.955       0.160
# 4           0.942             72.4    0.913       0.175
#
#    Perceptions_of_Corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292
# 3                      0.673
# ...

# %%
world_happiness_2021_df.to_csv('Cleaned_Data/World_Happiness_Report_2021.csv', index=False)

# %%
world_happiness_df.to_csv('Cleaned_Data/World_Happiness_Report_All_Years.csv', index=False)

# %%
world_happiness_df.dtypes
# Out:
# Country                       object
# Year                           int64
# World_Region                  object
# Happiness_Score              float64
# Economic_Production          float64
# Social_Support               float64
# Life_Expectancy              float64
# Freedom                      float64
# Generosity                   float64
# Perceptions_of_Corruption    float64
# dtype: object

# %%
world_happiness_df['World_Region'].astype(str)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1944    0
# 1945    0
# 1946    0
# 1947    0
# 1948    0
# Name: World_Region, Length: 1949, dtype: object

# %%
world_happiness_df['World_Region'] = "0"
world_happiness_df.head()
# Out:
#        Country  Year World_Region  Happiness_Score  Economic_Production  \
# 0  Afghanistan  2008            0            3.724                7.370
# 1  Afghanistan  2009            0            4.402                7.540
# 2  Afghanistan  2010            0            4.758                7.647
# 3  Afghanistan  2011            0            3.832                7.620
# 4  Afghanistan  2012            0            3.783                7.705
#
#    Social_Support  Life_Expectancy  Freedom  Generosity  \
# 0           0.451            50.80    0.718       0.168
# 1           0.552            51.20    0.679       0.190
# 2           0.539            51.60    0.600       0.121
# 3           0.521            51.92    0.496       0.162
# 4           0.521            52.24    0.531       0.236
#
#    Perceptions_of_Corruption
# 0                      0.882
# 1                      0.850
# 2                      0.707
# 3                      0.731
# 4                      0.776

# %%
joined_df = pd.read_csv("Cleaned_Data/WHR_Joined.csv")
joined_df.head()
# Out:
#    country  year    world_region  happiness_score  economic_production  \
# 0  Denmark  2005  Western Europe            8.019               10.851
# 1  Denmark  2008  Western Europe            7.971               10.880
# 2  Finland  2020  Western Europe            7.889               10.750
# 3  Finland  2018  Western Europe            7.858               10.783
# 4  Finland  2021  Western Europe            7.842               10.775
#
#    social_support  life_expectancy  freedom  generosity  \
# 0           0.972            69.60    0.971         NaN
# 1           0.954            70.08    0.970       0.272
# 2           0.962            72.10    0.962      -0.116
# 3           0.962            71.90    0.938      -0.127
# 4           0.954            72.00    0.949      -0.098
#
#    perceptions_of_corruption
# 0                      0.237
# 1                      0.248
# 2                      0.164
# 3                      0.199
# 4                      0.186

# %%
joined_df.describe()
# Out:
#               year  happiness_score  economic_production  social_support  \
# count  2098.000000      2098.000000          2062.000000     2085.000000
# mean   2013.768827         5.471402             9.373060        0.812709
# std       4.486449         1.112676             1.154247        0.118203
# min    2005.000000         2.375000             6.635000        0.290000
# 25%    2010.000000         4.652250             8.470500        0.750000
# 50%    2014.000000         5.392000             9.462000        0.835000
# 75%    2018.000000         6.282500            10.360750        0.905000
# max    2021.000000         8.019000            11.648000        0.987000
#
#        life_expectancy      freedom   generosity  perceptions_of_corruption
# count      2043.000000  2066.000000  2009.000000                1988.000000
# mean         63.478503     0.746094    -0.001027                   0.745650
# std           7.468780     0.140766     0.161400                   0.186261
# ...

# %%
import pandas as pd
import numpy as np

WHR_null_avg = pd.read_csv("Cleaned_Data/WHR_Joined_NullAvg.csv")
WHR_null_avg.head()
# Out:
#    country  year    world_region  happiness_score  economic_production  \
# 0  Denmark  2005  Western Europe            8.019               10.851
# 1  Denmark  2008  Western Europe            7.971               10.880
# 2  Finland  2020  Western Europe            7.889               10.750
# 3  Finland  2018  Western Europe            7.858               10.783
# 4  Finland  2021  Western Europe            7.842               10.775
#
#    social_support  life_expectancy  freedom  generosity  \
# 0           0.972            69.60    0.971    0.161533
# 1           0.954            70.08    0.970    0.272000
# 2           0.962            72.10    0.962   -0.116000
# 3           0.962            71.90    0.938   -0.127000
# 4           0.954            72.00    0.949   -0.098000
#
#    perceptions_of_corruption
# 0                      0.237
# 1                      0.248
# 2                      0.164
# 3                      0.199
# 4                      0.186

# %%
df1 = WHR_null_avg[WHR_null_avg.isna().any(axis=1)]
df1
# Out:
#                 country  year                  world_region  happiness_score  \
# 293                Oman  2011  Middle East and North Africa            6.853
# 966             Somalia  2014            Sub-Saharan Africa            5.528
# 1036               Cuba  2006   Latin America and Caribbean            5.418
# 1075            Somalia  2015            Sub-Saharan Africa            5.354
# 1302  Somaliland region  2012            Sub-Saharan Africa            5.057
# 1350  Somaliland region  2009            Sub-Saharan Africa            4.991
# 1388  Somaliland region  2011            Sub-Saharan Africa            4.931
# 1558            Somalia  2016            Sub-Saharan Africa            4.668
# 1566  Somaliland region  2010            Sub-Saharan Africa            4.657
# 1878        South Sudan  2015            Sub-Saharan Africa            4.071
# 1949        South Sudan  2014            Sub-Saharan Africa            3.832
# ...

# %%
WHR_noNull = WHR_null_avg.dropna()
WHR_noNull.head()
# Out:
#    country  year    world_region  happiness_score  economic_production  \
# 0  Denmark  2005  Western Europe            8.019               10.851
# 1  Denmark  2008  Western Europe            7.971               10.880
# 2  Finland  2020  Western Europe            7.889               10.750
# 3  Finland  2018  Western Europe            7.858               10.783
# 4  Finland  2021  Western Europe            7.842               10.775
#
#    social_support  life_expectancy  freedom  generosity  \
# 0           0.972            69.60    0.971    0.161533
# 1           0.954            70.08    0.970    0.272000
# 2           0.962            72.10    0.962   -0.116000
# 3           0.962            71.90    0.938   -0.127000
# 4           0.954            72.00    0.949   -0.098000
#
#    perceptions_of_corruption
# 0                      0.237
# 1                      0.248
# 2                      0.164
# 3                      0.199
# 4                      0.186

# %%
df3 = WHR_noNull[WHR_noNull.isna().any(axis=1)]
df3
# Out:
# Empty DataFrame
# Columns: [country, year, world_region, happiness_score, economic_production, social_support, life_expectancy, freedom, generosity, perceptions_of_corruption]
# Index: []

# %%
WHR_noNull.to_csv('Cleaned_Data/WHR_noNull.csv', index=False)
